# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import warnings
import seaborn as sns
#from sklearn.datasets import make_blobs
from sklearn.decomposition import PCA

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical

# %%
plt.style.use('seaborn')

# %% [markdown]
# Diketahui data kondisi tubuh serta potensi penyakit jantung dari 303 responden sebagai berikut :

# %%
df = pd.DataFrame(pd.read_csv('./heart_disease.txt', sep= ','))
len(df)
# Out:
# 303

# %%
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %% [markdown]
# Complete attribute documentation:
#
#
#       3 age: age in years
#       4 sex: sex (1 = male; 0 = female)
#       9 cp: chest pain type
#         -- Value 1: typical angina
#         -- Value 2: atypical angina
#         -- Value 3: non-anginal pain
#         -- Value 4: asymptomatic
#      10 trestbps: resting blood pressure (in mm Hg on admission to the
#         hospital)
#      12 chol: serum cholestoral in mg/dl
#      16 fbs: (fasting blood sugar > 120 mg/dl)  (1 = true; 0 = false)
#      19 restecg: resting electrocardiographic results
#         -- Value 0: normal
#         -- Value 1: having ST-T wave abnormality (T wave inversions and/or ST
#                     elevation or depression of > 0.05 mV)
#         -- Value 2: showing probable or definite left ventricular hypertrophy
#                     by Estes' criteria
#      32 thalach: maximum heart rate achieved
#      38 exang: exercise induced angina (1 = yes; 0 = no)
#      40 oldpeak = ST depression induced by exercise relative to rest
#      41 slope: the slope of the peak exercise ST segment
#         -- Value 1: upsloping
#         -- Value 2: flat
#         -- Value 3: downsloping
#      44 ca: number of major vessels (0-3) colored by flourosopy
#
#      51 thal: 3 = normal; 6 = fixed defect; 7 = reversable defect
#      58 num: diagnosis of heart disease (angiographic disease status)
#         -- Value 0: < 50% diameter narrowing
#         -- Value 1,2,3,4: > 50% diameter narrowing
#         (in any major vessel: attributes 59 through 68 are vessels)

# %% [markdown]
# # CLEANING DATA
#
# Tipe variabel :
# - Binary: sex, fbs, exang
# - Categorical: cp, restecg, slope, ca, thal, num(target)
# - Continuous: age, trestbps, chol, thalac, oldpeak

# %% [markdown]
# 1. Menghapus baris dengan objek tidak dikenal

# %%
xx=np.where(df=='?')
xx
# Out:
# (array([ 87, 166, 192, 266, 287, 302], dtype=int64),
#  array([12, 11, 11, 12, 11, 11], dtype=int64))

# %% [markdown]
# for i in range(0,len(xx[0])):
#     row = xx[0][i]
#     col = xx[1][i]
#     df.iloc[row,col] = np.NaN

# %%
df=df.drop(xx[0],axis=0)

# %%
len(df)
# Out:
# 297

# %% [markdown]
# 2. Mengubah kolom binary dan categorical ke integer

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     50
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            4
# thal          3
# num           5
# dtype: int64

# %%
df.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca           object
# thal         object
# num           int64
# dtype: object

# %%
#Change float to int
for i in ['sex','fbs','exang','cp','restecg','slope']:
    df[i]=df[i].astype(int)

# %%
#change object to int
df['ca']=df['ca'].astype(float).astype(int)
df['thal']=df['thal'].astype(float).astype(int)

# %%
df.dtypes
# Out:
# age         float64
# sex           int32
# cp            int32
# trestbps    float64
# chol        float64
# fbs           int32
# restecg       int32
# thalach     float64
# exang         int32
# oldpeak     float64
# slope         int32
# ca            int32
# thal          int32
# num           int64
# dtype: object

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     50
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            4
# thal          3
# num           5
# dtype: int64

# %% [markdown]
# 3. Cek duplikat

# %%
#check for duplicate rows
duplicates = df.duplicated().sum()
duplicates
# Out:
# 0

# %%
all(df.isnull()==False)
# Out:
# True

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS :
#
#
# Distribusi tiap atribut sebagai berikut :

# %%
warnings.filterwarnings('ignore')
nums = df
plt.figure(figsize=(25,80))
for i, column in ['age','trestbps','chol','thalach','oldpeak']:
    plt.subplot(25, 1, i+1); sns.distplot(nums[column])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11860/947085417.py in <module>
#       2 nums = df
#       3 plt.figure(figsize=(25,80))
# ----> 4 for i, column in ['age','trestbps','chol','thalach','oldpeak']:
#       5     plt.subplot(25, 1, i+1); sns.distplot(nums[column])
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# Persentase jumlah data tiap kategori kolom yang menyatakan diagnosis ('num') sebagai berikut :

# %%
ax = sns.barplot(x='num', y="num", data=df, estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %% [markdown]
# Untuk menyederhanakan klasifikasi dan membuat data balance, kategori 1, 2, 3, dan 4 akan disatukan sebagai 2 kategori pada kolom "potential" (nilai 0 untuk kondisi tidak berpotensi dan 1 untuk kondisi berpotensi penyakit jantung)

# %%
potential = []
for i in df.num:
    if i==0:
        potential.append(0)
    else:
        potential.append(1)
df['potential'] = potential

# %%
ax = sns.barplot(x='potential', y="potential", data=df, estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %% [markdown]
# Data potential sudah cukup seimbang antara yang berpotensi dan yang tidak berpotensi.
# Sekarang akan lanjut analisis tiap feature

# %% [markdown]
# Selanjutnya, akan dilihat korelasi linier dari tiap atribut.

# %%
### LINEAR CORRELATION
plt.figure(figsize=(12,12))
linearCorr = df.corr()
sns.heatmap(linearCorr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Tidak ada atribut yg saling berkolerasi secara linier dengan "potential", sehingga problem ini tidak dapat menggunakan algoritma regresi linier. Selanjutnya diperlukan pemilihan atribut-atribut yang penting/berpengaruh untuk prediksi dengan menggunakan algoritma deep learning.

# %% [markdown]
# Membuat df_pred, yaitu dataframe untuk menyimpan semua atribut

# %%
df_pred=df.drop(['num','potential'], axis=1)

# %% [markdown]
# Plot bar chart untuk melihat perbandingan distribusi tiap kategori berdasarkan target ('potential')

# %%
plt.figure(figsize=(15,15))
plt.subplot(4, 1, 1); sns.barplot(x='potential', y="potential", data=df, hue='sex', estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
plt.subplot(4, 1, 2); sns.barplot(x='potential', y="potential", data=df, hue='cp', estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
plt.subplot(4, 1, 3); sns.barplot(x='potential', y="potential", data=df, hue='fbs', estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
plt.subplot(4, 1, 4); sns.barplot(x='potential', y="potential", data=df, hue='exang', estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
plt.subplot(4, 1, 3); sns.barplot(x='potential', y="potential", data=df, hue='slope', estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
plt.subplot(4, 1, 4); sns.barplot(x='potential', y="potential", data=df, hue='ca', estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
# Out:
# [Text(17.200000000000003, 0.5, 'Percent')]

# %%
plt.figure(figsize=(15,15))
plt.subplot(4, 1, 4); sns.barplot(x='potential', y="potential", data=df, hue='restecg', estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
# Out:
# [Text(17.200000000000003, 0.5, 'Percent')]

# %%
plt.figure(figsize=(15,15))
plt.subplot(4, 1, 4); sns.barplot(x='potential', y="potential", data=df, hue='thal', estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")
# Out:
# [Text(17.200000000000003, 0.5, 'Percent')]

# %% [markdown]
# Dari bar chart di atas terlihat bahwa semua atribut tampak berpengaruh, sehingga semua akan digunakan sebagai fitur prediktor.

# %% [markdown]
# # TRAINING DATA

# %%
# split into train and test
n_train = 210
X = principalDf
#X = df_pred
y = np.array(df[['potential']])

trainX, validX = X[:n_train, :], X[n_train:, :]
trainy, validy = y[:n_train], y[n_train:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11208/4160287194.py in <module>
#       1 # split into train and test
#       2 n_train = 210
# ----> 3 X = principalDf
#       4 #X = df_pred
#       5 y = np.array(df[['potential']])
#
# NameError: name 'principalDf' is not defined

# %%
len(finalDf)
# Out:
# 303
